# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('covid_vaccine_statewise.csv')
dataset
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
dataset.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
dataset.isna().sum(axis=0)
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
print(dataset.median(axis=0))
# Out:
# Total Doses Administered                 818202.0
# Sessions                                  45470.0
#  Sites                                      597.0
# First Dose Administered                  661459.0
# Second Dose Administered                 138818.0
# Male (Doses Administered)                389785.0
# Female (Doses Administered)              334238.0
# Transgender (Doses Administered)            113.0
#  Covaxin (Doses Administered)             11851.0
# CoviShield (Doses Administered)          756736.0
# Sputnik V (Doses Administered)                0.0
# AEFI                                        294.0
# 18-44 Years (Doses Administered)        3095970.0
# 45-60 Years (Doses Administered)        2695938.0
# 60+ Years (Doses Administered)          1805696.5
# 18-44 Years(Individuals Vaccinated)      294727.0
# 45-60 Years(Individuals Vaccinated)      833039.5
# 60+ Years(Individuals Vaccinated)        788742.5
# Male(Individuals Vaccinated)           37165905.0
# ...

# %%
dataset
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
analysis = dataset.groupby(['State']).sum()
analysis
# Out:
#                                           Total Doses Administered  \
# State
# Andaman and Nicobar Islands                           2.054441e+07
# Andhra Pradesh                                        1.591678e+09
# Arunachal Pradesh                                     6.093730e+07
# Assam                                                 7.163890e+08
# Bihar                                                 1.741293e+09
# Chandigarh                                            5.629684e+07
# Chhattisgarh                                          9.681233e+08
# Dadra and Nagar Haveli and Daman and Diu              3.818948e+07
# Delhi                                                 8.125584e+08
# Goa                                                   9.218954e+07
# Gujarat                                               2.732064e+09
# Haryana                                               9.144544e+08
# Himachal Pradesh                                      3.901326e+08
# ...

# %%
dataset.groupby('State')['First Dose Administered'].sum()
# Out:
# State
# Andaman and Nicobar Islands                 1.642585e+07
# Andhra Pradesh                              1.232861e+09
# Arunachal Pradesh                           4.900498e+07
# Assam                                       5.856002e+08
# Bihar                                       1.470503e+09
# Chandigarh                                  4.470310e+07
# Chhattisgarh                                7.960029e+08
# Dadra and Nagar Haveli and Daman and Diu    3.359506e+07
# Delhi                                       6.243395e+08
# Goa                                         7.599137e+07
# Gujarat                                     2.131646e+09
# Haryana                                     7.557984e+08
# Himachal Pradesh                            3.162940e+08
# India                                       2.826214e+10
# Jammu and Kashmir                           4.101018e+08
# Jharkhand                                   6.036737e+08
# ...

# %%
dataset.groupby('State')['Second Dose Administered'].sum()
# Out:
# State
# Andaman and Nicobar Islands                 4.118554e+06
# Andhra Pradesh                              3.588176e+08
# Arunachal Pradesh                           1.193232e+07
# Assam                                       1.307888e+08
# Bihar                                       2.707906e+08
# Chandigarh                                  1.159374e+07
# Chhattisgarh                                1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu    4.594416e+06
# Delhi                                       1.882189e+08
# Goa                                         1.619817e+07
# Gujarat                                     6.004184e+08
# Haryana                                     1.586561e+08
# Himachal Pradesh                            7.383858e+07
# India                                       6.759621e+09
# Jammu and Kashmir                           8.595165e+07
# Jharkhand                                   1.221211e+08
# ...

# %%
dataset['Male(Individuals Vaccinated)'].sum()
# Out:
# 7138698858.0

# %%
print(dataset['Female(Individuals Vaccinated)'].sum())
# Out:
# 6321628736.0

# %%
x = dataset.groupby('State')

# %%
x

# %%
x['Second Dose Administered'].sum()
# Out:
# State
# Andaman and Nicobar Islands                 4.118554e+06
# Andhra Pradesh                              3.588176e+08
# Arunachal Pradesh                           1.193232e+07
# Assam                                       1.307888e+08
# Bihar                                       2.707906e+08
# Chandigarh                                  1.159374e+07
# Chhattisgarh                                1.721204e+08
# Dadra and Nagar Haveli and Daman and Diu    4.594416e+06
# Delhi                                       1.882189e+08
# Goa                                         1.619817e+07
# Gujarat                                     6.004184e+08
# Haryana                                     1.586561e+08
# Himachal Pradesh                            7.383858e+07
# India                                       6.759621e+09
# Jammu and Kashmir                           8.595165e+07
# Jharkhand                                   1.221211e+08
# ...

# %%
for i in x['Second Dose Administered'].sum():
    print(i)
# Out:
# 4118554.0
# 358817595.0
# 11932317.0
# 130788792.0
# 270790571.0
# 11593735.0
# 172120400.0
# 4594416.0
# 188218946.0
# 16198174.0
# 600418376.0
# 158656058.0
# 73838582.0
# 6759621451.0
# 85951651.0
# 122121060.0
# 427187178.0
# 364048753.0
# 5453762.0
# 1056446.0
# 316932957.0
# 712881086.0
# 11858150.0
# 12166633.0
# 9998418.0
# 9204637.0
# 251302794.0
# 8608859.0
# 121120995.0
# 491702988.0
# 9723640.0
# 290670622.0
# 198152946.0
# 65270138.0
# 554435112.0
# 100085040.0
# 586146880.0

# %%
import seaborn as sns

# %%
sns.boxplot(x= x['First Dose Administered'].sum())
# Out:
# <AxesSubplot:xlabel='First Dose Administered'>

# %%
sns.boxplot(x='Male(Individuals Vaccinated)',data=dataset)
# Out:
# <AxesSubplot:xlabel='Male(Individuals Vaccinated)'>

# %%
x.all()
# Out:
#                                           Updated On  \
# State
# Andaman and Nicobar Islands                     True
# Andhra Pradesh                                  True
# Arunachal Pradesh                               True
# Assam                                           True
# Bihar                                           True
# Chandigarh                                      True
# Chhattisgarh                                    True
# Dadra and Nagar Haveli and Daman and Diu        True
# Delhi                                           True
# Goa                                             True
# Gujarat                                         True
# Haryana                                         True
# Himachal Pradesh                                True
# India                                           True
# Jammu and Kashmir                               True
# Jharkhand                                       True
# ...

# %%
sns.boxplot(x='Female (Doses Administered)',y='State',data=dataset)
# Out:
# <AxesSubplot:xlabel='Female (Doses Administered)', ylabel='State'>

# %%
for i in x['Total Doses Administered'].sum():
    print(i)
# Out:
# 20544408.0
# 1591678440.0
# 60937297.0
# 716389018.0
# 1741293449.0
# 56296840.0
# 968123302.0
# 38189479.0
# 812558419.0
# 92189542.0
# 2732064385.0
# 914454410.0
# 390132586.0
# 35021766242.0
# 496053428.0
# 725794786.0
# 2300517146.0
# 1557893825.0
# 23263011.0
# 5420101.0
# 2113537548.0
# 3497245417.0
# 79267718.0
# 74782607.0
# 57871495.0
# 51615403.0
# 1283935962.0
# 49955717.0
# 705467577.0
# 2692747175.0
# 46704569.0
# 1579203134.0
# 1078473591.0
# 257959864.0
# 3342846470.0
# 463276486.0
# 2382596869.0
